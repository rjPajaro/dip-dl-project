# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Create an ImageDataGenerator with augmentation settings
datagen = ImageDataGenerator(rotation_range=3)

# %% [markdown]
# # U-Net

# %%
# import pickle

# folder = '../pickles/pure_amd_pickled'

# pickle_in = open(folder + '/' + 'ODIR_AMD_w_others_pred.pickle','rb')
# ODIR_AMD_w_others = pickle.load(pickle_in)

# pickle_in = open(folder + '/' + 'ODIR_Pure_AMD_pred.pickle','rb')
# ODIR_Pure_AMD = pickle.load(pickle_in)

# pickle_in = open(folder + '/' + 'RFMID_AMD_w_others_pred.pickle','rb')
# RFMID_AMD_w_others = pickle.load(pickle_in)

# pickle_in = open(folder + '/' + 'RFMID_Pure_AMD_pred.pickle','rb')
# RFMID_Pure_AMD = pickle.load(pickle_in)

# pickle_in = open(folder + '/' + 'RFMID_normal_pred.pickle','rb')
# RFMID_normal = pickle.load(pickle_in)

# pickle_in = open(folder + '/' + 'stare_AMD_w_others_pred.pickle','rb')
# stare_AMD_w_others = pickle.load(pickle_in)

# pickle_in = open(folder + '/' + 'stare_normal_pred.pickle','rb')
# stare_normal = pickle.load(pickle_in)

# pickle_in = open(folder + '/' + 'ODIR_Normal_pred.pickle','rb')
# ODIR_Normal = pickle.load(pickle_in)

# %% [markdown]
# # CLAHE

# %%
import pickle

folder = '../pickles/clahe_pickles'

pickle_in = open(folder + '/' + 'ODIR_AMD_w_others_data.pickle','rb')
ODIR_AMD_w_others = pickle.load(pickle_in)

pickle_in = open(folder + '/' + 'ODIR_Pure_AMD_data.pickle','rb')
ODIR_Pure_AMD = pickle.load(pickle_in)

pickle_in = open(folder + '/' + 'ODIR_Normal_data.pickle','rb')
ODIR_normal = pickle.load(pickle_in)

pickle_in = open(folder + '/' + 'RFMID_AMD_w_others_data.pickle','rb')
RFMID_AMD_w_others = pickle.load(pickle_in)

pickle_in = open(folder + '/' + 'RFMID_Pure_AMD_data.pickle','rb')
RFMID_Pure_AMD = pickle.load(pickle_in)

pickle_in = open(folder + '/' + 'RFMID_normal_data.pickle','rb')
RFMID_normal = pickle.load(pickle_in)

pickle_in = open(folder + '/' + 'stare_AMD_w_others_data.pickle','rb')
stare_AMD_w_others = pickle.load(pickle_in)

pickle_in = open(folder + '/' + 'stare_normal_data.pickle','rb')
stare_normal = pickle.load(pickle_in)

# %%
len(ODIR_AMD_w_others)
# Out:
# 76

# %%
from PIL import Image
import numpy as np
from scipy.ndimage import rotate
import cv2
import imutils

# %%
stare_AMD_w_others_pred = []
stare_normal_pred = []
RFMiD_Pure_AMD_pred = []
RFMiD_AMD_w_others_pred = []
RFMiD_normal_pred = []
ODIR_Pure_AMD_pred = []
ODIR_AMD_w_others_pred = []
ODIR_Normal_pred = []

angle = 20

# Loop through ODIR_AMD_w_others and perform rotation for each image
for img in ODIR_AMD_w_others:
    rotated_image = imutils.rotate(img, angle=angle)

    ODIR_AMD_w_others_pred.append(img)
    ODIR_AMD_w_others_pred.append(rotated_image)

# # Loop through stare_AMD_w_others and perform rotation for each image
# for img in stare_AMD_w_others:
#     image = rotate(img, angle, reshape=False, prefilter=True)
#     stare_AMD_w_others_pred.append(img)
#     stare_AMD_w_others_pred.append(image)

# # Loop through stare_normal and perform rotation for each image
# for img in stare_normal:
#     image = rotate(img, angle, reshape=False, prefilter=True)
#     stare_normal_pred.append(img)
#     stare_normal_pred.append(image)

# # Loop through RFMiD_Pure_AMD and perform rotation for each image
# for img in RFMID_Pure_AMD:
#     image = rotate(img, angle, reshape=False, prefilter=True)
#     RFMiD_Pure_AMD_pred.append(img)
#     RFMiD_Pure_AMD_pred.append(image)

# # Loop through RFMiD_AMD_w_others and perform rotation for each image
# for img in RFMID_AMD_w_others:
#     image = rotate(img, angle, reshape=False, prefilter=True)
#     RFMiD_AMD_w_others_pred.append(img)
#     RFMiD_AMD_w_others_pred.append(image)

# # Loop through RFMiD_normal and perform rotation for each image
# for img in RFMID_normal:
#     image = rotate(img, angle, reshape=False, prefilter=True)
#     RFMiD_normal_pred.append(img)
#     RFMiD_normal_pred.append(image)

# # Loop through ODIR_Pure_AMD and perform rotation for each image
# for img in ODIR_Pure_AMD:
#     image = rotate(img, angle, reshape=False, prefilter=True)
#     ODIR_Pure_AMD_pred.append(img)
#     ODIR_Pure_AMD_pred.append(image)

# # Loop through ODIR_Normal and perform rotation for each image
# for img in ODIR_normal:
#     image = rotate(img, angle, reshape=False, prefilter=True)
#     ODIR_Normal_pred.append(img)
#     ODIR_Normal_pred.append(image)

# %%
len(ODIR_AMD_w_others_pred)
# Out:
# 152

# %%
# # Saving Data
# import pickle
# import dill

# folder = '../data/augmented-data/U-Net/STARE'

# pickle_stare_AMD_w_others_pred = open(folder+"/"+"stare_AMD_w_others_pred.pickle","wb")
# pickle.dump(stare_AMD_w_others_pred, pickle_stare_AMD_w_others_pred)
# pickle_stare_AMD_w_others_pred.close()

# pickle_stare_normal_pred = open(folder+"/"+"stare_normal_pred.pickle","wb")
# pickle.dump(stare_normal_pred, pickle_stare_normal_pred)
# pickle_stare_normal_pred.close()

# folder = '../data/augmented-data/U-Net/RFMID'

# pickle_RFMiD_Pure_AMD_pred = open(folder+"/"+"RFMiD_Pure_AMD_pred.pickle","wb")
# pickle.dump(RFMiD_Pure_AMD_pred, pickle_RFMiD_Pure_AMD_pred)
# pickle_RFMiD_Pure_AMD_pred.close()

# pickle_RFMiD_AMD_w_others_pred = open(folder+"/"+"RFMiD_AMD_w_others_pred.pickle","wb")
# pickle.dump(RFMiD_AMD_w_others_pred, pickle_RFMiD_AMD_w_others_pred)
# pickle_RFMiD_AMD_w_others_pred.close()

# pickle_RFMiD_normal_pred = open(folder+"/"+"RFMiD_normal_pred.pickle","wb")
# pickle.dump(RFMiD_normal_pred, pickle_RFMiD_normal_pred)
# pickle_RFMiD_normal_pred.close()

# folder = '../data/augmented-data/U-Net/ODIR'

# pickle_ODIR_Pure_AMD_pred = open(folder+"/"+"ODIR_Pure_AMD_pred.pickle","wb")
# pickle.dump(ODIR_Pure_AMD_pred, pickle_ODIR_Pure_AMD_pred)
# pickle_ODIR_Pure_AMD_pred.close()

# pickle_ODIR_AMD_w_others_pred = open(folder+"/"+"ODIR_AMD_w_others_pred.pickle","wb")
# pickle.dump(ODIR_AMD_w_others_pred, pickle_ODIR_AMD_w_others_pred)
# pickle_ODIR_AMD_w_others_pred.close()

# pickle_ODIR_Normal_pred = open(folder+"/"+"ODIR_Normal_pred.pickle","wb")
# pickle.dump(ODIR_Normal_pred, pickle_ODIR_Normal_pred)
# pickle_ODIR_Normal_pred.close()

# %%
# # Saving Data
# import pickle
# import dill

# folder = '../data/augmented-data/CLAHE/STARE'

# pickle_stare_AMD_w_others_data = open(folder+"/"+"stare_AMD_w_others_data.pickle","wb")
# pickle.dump(stare_AMD_w_others_pred, pickle_stare_AMD_w_others_data)
# pickle_stare_AMD_w_others_data.close()

# pickle_stare_normal_data = open(folder+"/"+"stare_normal_data.pickle","wb")
# pickle.dump(stare_normal_pred, pickle_stare_normal_data)
# pickle_stare_normal_data.close()

# folder = '../data/augmented-data/CLAHE/RFMID'

# pickle_RFMiD_Pure_AMD_data = open(folder+"/"+"RFMiD_Pure_AMD_data.pickle","wb")
# pickle.dump(RFMiD_Pure_AMD_pred, pickle_RFMiD_Pure_AMD_data)
# pickle_RFMiD_Pure_AMD_data.close()

# pickle_RFMiD_AMD_w_others_data = open(folder+"/"+"RFMiD_AMD_w_others_data.pickle","wb")
# pickle.dump(RFMiD_AMD_w_others_pred, pickle_RFMiD_AMD_w_others_data)
# pickle_RFMiD_AMD_w_others_data.close()

# pickle_RFMiD_normal_data = open(folder+"/"+"RFMiD_normal_data.pickle","wb")
# pickle.dump(RFMiD_normal_pred, pickle_RFMiD_normal_data)
# pickle_RFMiD_normal_data.close()

# folder = '../data/augmented-data/CLAHE/ODIR'

# pickle_ODIR_Pure_AMD_data = open(folder+"/"+"ODIR_Pure_AMD_data.pickle","wb")
# pickle.dump(ODIR_Pure_AMD_pred, pickle_ODIR_Pure_AMD_data)
# pickle_ODIR_Pure_AMD_data.close()

# pickle_ODIR_AMD_w_others_data = open(folder+"/"+"ODIR_AMD_w_others_data.pickle","wb")
# pickle.dump(ODIR_AMD_w_others_pred, pickle_ODIR_AMD_w_others_data)
# pickle_ODIR_AMD_w_others_data.close()

# pickle_ODIR_Normal_data = open(folder+"/"+"ODIR_Normal_data.pickle","wb")
# pickle.dump(ODIR_Normal_pred, pickle_ODIR_Normal_data)
# pickle_ODIR_Normal_data.close()

# %%
# import matplotlib.pyplot as plt

# # Define the number of rows and columns for the grid.
# rows = 1
# columns = 3

# # Create a figure and subplots with the specified number of rows and columns.
# fig, axs = plt.subplots(rows, columns, figsize=(12, 4))

# # Plot each image in its corresponding subplot.
# for i, image in enumerate(ODIR_AMD_w_others_pred):
#     axs[i].imshow(image, cmap='gray')  # Use 'gray' colormap for grayscale images.
#     axs[i].axis('off')  # Hide the axes ticks and labels.

# # Display the plots.
# plt.show()

# %%
from matplotlib import pyplot as plt

for i in range(4):
    plt.imshow(ODIR_AMD_w_others_pred[i], interpolation='nearest', cmap='gray')
    plt.show()
